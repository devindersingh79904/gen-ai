# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
name = os.getenv("NAME")
if name:
    print(f"Hello {name}")
else:
    print("Hello World")
# Out:
# Hello DEVINDER_PANEESAR
